# %% [markdown]
# # Iris Project
# ## Data Exploration and Analysis

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
sns.set(color_codes=True)
# %matplotlib inline

# %%
df=pd.read_csv("C:/Users/neeru singla/Desktop/Iris/iris.data",header=-1)
#df

# %%
cols=['sepal_length','sepal_width','petal_length','petal_width','class']
df.columns=cols
#df.head()

# %% [markdown]
# ## Iris data from seaborn

# %%
iris=sns.load_dataset('iris')
#iris.head()

# %% [markdown]
# ## Visualization

# %%
sns.pairplot(iris,hue='species',size=3,aspect=1)

# %%
iris.hist(edgecolor='red',linewidth=1.2,figsize=(12,8))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000000001D70E278>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000000001D88D7F0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000000001D626F60>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000000001D980710>]],
#       dtype=object)

# %%
plt.figure(figsize=(12,8))
plt.subplot(2,2,1)
sns.violinplot(x='species',y='sepal_length',data=iris)
plt.subplot(2,2,2)
sns.violinplot(x='species',y='sepal_width',data=iris)
plt.subplot(2,2,3)
sns.violinplot(x='species',y='petal_length',data=iris)
plt.subplot(2,2,4)
sns.violinplot(x='species',y='petal_width',data=iris)

# %%
iris.boxplot(by='species',figsize=(12,8))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000000001E60B7F0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000000001EBE72B0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000000001EC18780>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000000001EC4CC50>]],
#       dtype=object)

# %%
pd.plotting.scatter_matrix(iris,figsize=(12,8))
plt.show()
